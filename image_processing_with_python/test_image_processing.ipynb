# %%
from skimage import data

# %%
rocket_image = data.rocket()
rocket_image
# Out:
# array([[[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  7,  18,  36]],
#
#        [[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        [[ 18,  34,  59],
#         [ 18,  34,  59],
#         [ 18,  34,  60],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        ...,
#
#        [[ 27,  28,  32],
#         [ 29,  29,  37],
#         [ 20,  24,  36],
#         ...,
#         [136, 106,  82],
#         [186, 136,  85],
#         [173, 119,  81]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 30,  34,  46],
#         ...,
#         [103,  67,  45],
#         [ 97,  61,  27],
#         [ 76,  49,  20]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 40,  46,  60],
#         ...,
#         [ 82,  53,  37],
#         [ 79,  50,  32],
#         [ 83,  61,  37]]], dtype=uint8)

# %%
from skimage import color
grayscale = color.rgb2gray(original.jpg)
rgb = color.gray2rgb(grayscale)
rgb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d646f7f1eb0f> in <module>
#       1 from skimage import color
# ----> 2 grayscale = color.rgb2gray(original.jpg)
#       3 rgb = color.gray2rgb(grayscale)
#       4 rgb
#
# NameError: name 'original' is not defined

# %%
def show_image(image, title = 'Image', cmap_type = 'gray'):
    plt.imshow(image,cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
from skimage import color 
grayscale = color.rgb2gray('original.jpg')
show_image(grayscale,"Grayscale")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b24dc4240399> in <module>
#       1 from skimage import color
# ----> 2 grayscale = color.rgb2gray('original.jpg')
#       3 show_image(grayscale,"Grayscale")
#
# ~\Anaconda3\lib\site-packages\skimage\color\colorconv.py in rgb2gray(rgb)
#     794     """
#     795
# --> 796     if rgb.ndim == 2:
#     797         return np.ascontiguousarray(rgb)
#     798
#
# AttributeError: 'str' object has no attribute 'ndim'

# %%
img = rgb2gray(imread('image.png'));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-89c486cae330> in <module>
# ----> 1 img = rgb2gray(imread('image.png'));
#
# NameError: name 'rgb2gray' is not defined

# %%
import matplotlib.image as mpimg
img = mpimg.imread('original.jpg')
lum_img = img[:,:,0]

# %%
import numpy as np

def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

img = mpimg.imread('original.jpg')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap=plt.get_cmap('gray'), vmin=0, vmax=1)
plt.show()

# %%
from skimage import io
img = io.imread('original.jpg', as_gray=True)
img_original = io.imread('original.jpg', as_gray=False)

show_image(img,'Grayscale image')
show_image(img_original,'Original image')

# %% [markdown]
# Exercise
# Exercise
# RGB to grayscale
# In this exercise you will load an image from scikit-image module data and make it grayscale, then compare both of them in the output.
#
# We have preloaded a function show_image(image, title='Image') that displays the image using Matplotlib. You can check more about its parameters using ?show_image() or help(show_image) in the console.
#
# Rocket
# Instructions
# 0 XP
# Instructions
# 0 XP
# Import the data and color modules from Scikit image. The first module provides example images, and the second, color transformation functions.
# Load the rocket image.
# Convert the RGB-3 rocket image to grayscale.
#
#
#
# Incorrect Submission
# Check your call of color.rgb2gray(). Did you correctly specify the first argument? Expected something different.
# Did you find this feedback helpful?
#
#
# Yes
#
# No
# +0 XP
# Great! You converted an image to grayscale. For many applications of image processing, color information doesn't help us identify important edges or other features. Something that we will cover later in the course.

# %%
# Import the modules from skimage
from skimage import data, color

# Load the rocket image
rocket = data.chelsea()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket) 

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

# %%
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.
